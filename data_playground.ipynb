# %%
import os, sys
sys.path.append(os.path.abspath("."))
from src.utils.load_data import load_all_data

# %%
fsi = load_all_data()
fsi.head()
# Out:
#                   VIX  Spread        CDS       FSI
# Date
# 2010-02-03  21.600000    6.46  12.678201  0.448641
# 2010-02-04  26.080000    6.59  12.678201  0.699886
# 2010-02-05  26.110001    6.81  12.678201  0.757714
# 2010-02-06  26.110001    6.81  12.678201  0.757714
# 2010-02-07  26.110001    6.81  12.678201  0.757714

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))
fsi[["VIX", "Spread", "CDS"]].plot(ax=ax)
ax.set_title("FSI components")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 4))
fsi["FSI"].plot(ax=ax, color="black")
ax.set_title("Financial Stress Index")
plt.show()

# %%
fsi[["VIX", "Spread", "CDS", "FSI"]].corr()
# Out:
#              VIX    Spread       CDS       FSI
# VIX     1.000000  0.511156 -0.210448  0.869692
# Spread  0.511156  1.000000 -0.682304  0.554195
# CDS    -0.210448 -0.682304  1.000000  0.071709
# FSI     0.869692  0.554195  0.071709  1.000000
